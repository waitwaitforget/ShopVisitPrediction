# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import pickle, os, re, operator, gc
from tqdm import tqdm
from multiprocessing import Pool
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
# import lightgbm as lgb
import xgboost as xgb

# %%
# load datasets
df_shopinfo = pd.read_csv('../data/shopInfo.txt', delimiter='\t')
df_shopcat = pd.read_csv('../data/shopCategoryInfo.txt', delimiter='\t')
df_trainset = pd.read_csv('../data/trainSampleInfo.txt', delimiter='\t')
df_testset = pd.read_csv('../data/testSampleInfo.txt', delimiter='\t')

df_shopinfo = df_shopinfo.merge(df_shopcat, on='category_id', how='left')
train = df_trainset.merge(df_shopinfo, how='left', on='shop_id')
train['row_id'] = train.index

# test = df_testset.merge(df_shopinfo, how='left', on='shop_id')
# test['row_id'] = test.index

# %%
train.head()
# Out:
#   shop_id  longitude_x  latitude_x  \
# 0      -1   117.086205   39.393679
# 1  S03097   119.357683   26.043137
# 2  S01259   120.138415   30.277816
# 3      -1   117.238163   31.813781
# 4  S00453   114.580855   30.660663
#
#                                           wifi_infos build_id category_id  \
# 0  M0000387352,-79;M0000599183,-80;M0000378675,-8...      NaN         NaN
# 1  M0000192366,-86;M0000736040,-71;M0000787437,-7...   B00098      C00004
# 2  M0000523931,-80;M0000284055,-83;M0000229302,-8...      NaN      C00004
# 3  M0000928623,-47;M0000033605,-48;M0000394309,-5...      NaN         NaN
# 4  M0000925767,-35;M0000446747,-36;M0000420052,-4...      NaN      C00006
#
#     layer   hot  longitude_y  latitude_y category_name  row_id
# 0     NaN   NaN          NaN         NaN           NaN       0
# 1     1.0   7.0   119.357681   26.043318            购物       1
# 2  1000.0  10.0   120.143157   30.275619            购物       2
# 3     NaN   NaN          NaN         NaN           NaN       3
# 4  1000.0   7.0   114.585922   30.657966          生活服务       4

# %%
build_id = 'B00098'

# %%
sub_train = train[train.build_id == build_id]

# %%
sub_train
# Out:
#         shop_id  longitude_x  latitude_x  \
# 1        S03097   119.357683   26.043137
# 1122     S03054   119.357949   26.042583
# 1459     S03054   119.357094   26.042793
# 1608     S03097   119.357854   26.043286
# 1765     S03097   119.357745   26.043318
# ...         ...          ...         ...
# 1201843  S03054   119.357450   26.042749
# 1202697  S03097   119.357781   26.043496
# 1203801  S03054   119.357350   26.043063
# 1204490  S03054   119.357595   26.042855
# 1204723  S03097   119.357703   26.043205
#
#                                                 wifi_infos build_id  \
# 1        M0000192366,-86;M0000736040,-71;M0000787437,-7...   B00098
# 1122     M0000206579,-72;M0000010195,-73;M0000920385,-7...   B00098
# 1459     M0000778589,-65;M0000206579,-68;M0000104914,-7...   B00098
# 1608     M0000911235,-58;M0000923071,-59;M0000789568,-6...   B00098
# 1765     M0000562185,-49;M0000630779,-68;M0000075828,-7...   B00098
# ...                                                    ...      ...
# 1201843  M0000398830,-73;M0000504132,-77;M0000627902,-7...   B00098
# 1202697  M0000562185,-48;M0000630779,-68;M0000075828,-6...   B00098
# 1203801  M0000206579,-55;M0000772175,-57;M0000010195,-6...   B00098
# 1204490  M0000670552,-72;M0000770093,-73;M0000065922,-7...   B00098
# 1204723  M0000562185,-56;M0000214833,-57;M0000641486,-6...   B00098
#
#         category_id  layer  hot  longitude_y  latitude_y category_name  \
# 1            C00004    1.0  7.0   119.357681   26.043318            购物
# 1122         C00004    2.0  4.0   119.357457   26.042785            购物
# 1459         C00004    2.0  4.0   119.357457   26.042785            购物
# 1608         C00004    1.0  7.0   119.357681   26.043318            购物
# 1765         C00004    1.0  7.0   119.357681   26.043318            购物
# ...             ...    ...  ...          ...         ...           ...
# 1201843      C00004    2.0  4.0   119.357457   26.042785            购物
# 1202697      C00004    1.0  7.0   119.357681   26.043318            购物
# 1203801      C00004    2.0  4.0   119.357457   26.042785            购物
# 1204490      C00004    2.0  4.0   119.357457   26.042785            购物
# 1204723      C00004    1.0  7.0   119.357681   26.043318            购物
#
#           row_id
# 1              1
# 1122        1122
# 1459        1459
# 1608        1608
# 1765        1765
# ...          ...
# 1201843  1201843
# 1202697  1202697
# 1203801  1203801
# 1204490  1204490
# 1204723  1204723
#
# [2595 rows x 12 columns]

# %%
train_set = []
for index, row in sub_train.iterrows():
    wifi_dict = {}
    for wifi in row.wifi_infos.split(';'):
        bssid, signal = wifi.split(',')
        wifi_dict[bssid] = int(signal)
    train_set.append(wifi_dict)

# %%
v = DictVectorizer(sparse=False, sort=False)

# %%
train_set = v.fit_transform(train_set)

# %%
train_set[train_set == 0] = np.NaN

# %%
sub_train = pd.concat([sub_train.reset_index(), pd.DataFrame(train_set)], axis=1)

# %%
sub_train
# Out:
#         index shop_id  longitude_x  latitude_x  \
# 0           1  S03097   119.357683   26.043137
# 1        1122  S03054   119.357949   26.042583
# 2        1459  S03054   119.357094   26.042793
# 3        1608  S03097   119.357854   26.043286
# 4        1765  S03097   119.357745   26.043318
# ...       ...     ...          ...         ...
# 2590  1201843  S03054   119.357450   26.042749
# 2591  1202697  S03097   119.357781   26.043496
# 2592  1203801  S03054   119.357350   26.043063
# 2593  1204490  S03054   119.357595   26.042855
# 2594  1204723  S03097   119.357703   26.043205
#
#                                              wifi_infos build_id category_id  \
# 0     M0000192366,-86;M0000736040,-71;M0000787437,-7...   B00098      C00004
# 1     M0000206579,-72;M0000010195,-73;M0000920385,-7...   B00098      C00004
# 2     M0000778589,-65;M0000206579,-68;M0000104914,-7...   B00098      C00004
# 3     M0000911235,-58;M0000923071,-59;M0000789568,-6...   B00098      C00004
# 4     M0000562185,-49;M0000630779,-68;M0000075828,-7...   B00098      C00004
# ...                                                 ...      ...         ...
# 2590  M0000398830,-73;M0000504132,-77;M0000627902,-7...   B00098      C00004
# 2591  M0000562185,-48;M0000630779,-68;M0000075828,-6...   B00098      C00004
# 2592  M0000206579,-55;M0000772175,-57;M0000010195,-6...   B00098      C00004
# 2593  M0000670552,-72;M0000770093,-73;M0000065922,-7...   B00098      C00004
# 2594  M0000562185,-56;M0000214833,-57;M0000641486,-6...   B00098      C00004
#
#       layer  hot  longitude_y  ...  787 788  789  790  791  792  793  794  \
# 0       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...          ...  ...  ...  ..  ...  ...  ...  ...  ...  ...
# 2590    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2591    1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2592    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2593    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2594    1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       795  796
# 0     NaN  NaN
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# ...   ...  ...
# 2590  NaN  NaN
# 2591  NaN  NaN
# 2592  NaN  NaN
# 2593  NaN  NaN
# 2594  NaN  NaN
#
# [2595 rows x 810 columns]

# %%
lbl = LabelEncoder()
lbl.fit(list(sub_train['shop_id'].values))
# Out:
# LabelEncoder()

# %%
sub_train['label'] = lbl.transform(list(sub_train['shop_id'].values))

# %%
sub_train
# Out:
#         index shop_id  longitude_x  latitude_x  \
# 0           1  S03097   119.357683   26.043137
# 1        1122  S03054   119.357949   26.042583
# 2        1459  S03054   119.357094   26.042793
# 3        1608  S03097   119.357854   26.043286
# 4        1765  S03097   119.357745   26.043318
# ...       ...     ...          ...         ...
# 2590  1201843  S03054   119.357450   26.042749
# 2591  1202697  S03097   119.357781   26.043496
# 2592  1203801  S03054   119.357350   26.043063
# 2593  1204490  S03054   119.357595   26.042855
# 2594  1204723  S03097   119.357703   26.043205
#
#                                              wifi_infos build_id category_id  \
# 0     M0000192366,-86;M0000736040,-71;M0000787437,-7...   B00098      C00004
# 1     M0000206579,-72;M0000010195,-73;M0000920385,-7...   B00098      C00004
# 2     M0000778589,-65;M0000206579,-68;M0000104914,-7...   B00098      C00004
# 3     M0000911235,-58;M0000923071,-59;M0000789568,-6...   B00098      C00004
# 4     M0000562185,-49;M0000630779,-68;M0000075828,-7...   B00098      C00004
# ...                                                 ...      ...         ...
# 2590  M0000398830,-73;M0000504132,-77;M0000627902,-7...   B00098      C00004
# 2591  M0000562185,-48;M0000630779,-68;M0000075828,-6...   B00098      C00004
# 2592  M0000206579,-55;M0000772175,-57;M0000010195,-6...   B00098      C00004
# 2593  M0000670552,-72;M0000770093,-73;M0000065922,-7...   B00098      C00004
# 2594  M0000562185,-56;M0000214833,-57;M0000641486,-6...   B00098      C00004
#
#       layer  hot  longitude_y  ...  788 789  790  791  792  793  794  795  \
# 0       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2       2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4       1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...          ...  ...  ...  ..  ...  ...  ...  ...  ...  ...
# 2590    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2591    1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2592    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2593    2.0  4.0   119.357457  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2594    1.0  7.0   119.357681  ...  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#       796  label
# 0     NaN      1
# 1     NaN      0
# 2     NaN      0
# 3     NaN      1
# 4     NaN      1
# ...   ...    ...
# 2590  NaN      0
# 2591  NaN      1
# 2592  NaN      0
# 2593  NaN      0
# 2594  NaN      1
#
# [2595 rows x 811 columns]

# %%
num_class = sub_train['label'].max() + 1

# %%
feature = [x for x in sub_train.columns if x not in ['index','label', 'shop_id', 'wifi_infos','category_id', 'category_name', 'build_id', 'row_id']]

# %%
params = {
    'booster': 'gbtree',
        'objective': 'binary:logistic',
        'eta': 0.1,
        'max_depth': 8,
        'eval_metric': 'auc',
        'seed': 0,
        'silent': 1
    }

# %%
sub_train[feature].shape, sub_train['label'].shape
# Out:
# ((2595, 803), (2595,))

# %%
X = sub_train[feature]
Y = sub_train['label']
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=123)
xgbtrain = xgb.DMatrix(X_train, Y_train)
xgbtest = xgb.DMatrix(X_test, Y_test)

# %%
# watchlist = [(xgbtrain, 'train'), (xgbtrain, 'test')]
model = xgb.cv(params, xgbtrain, num_boost_round=100, verbose_eval=True)
# Out:
# [0]	train-auc:1+0	test-auc:1+0
# [1]	train-auc:1+0	test-auc:1+0
# [2]	train-auc:1+0	test-auc:1+0
# [3]	train-auc:1+0	test-auc:1+0
# [4]	train-auc:1+0	test-auc:1+0
# [5]	train-auc:1+0	test-auc:1+0
# [6]	train-auc:1+0	test-auc:1+0
# [7]	train-auc:1+0	test-auc:1+0
# [8]	train-auc:1+0	test-auc:1+0
# [9]	train-auc:1+0	test-auc:1+0
# [10]	train-auc:1+0	test-auc:1+0
# [11]	train-auc:1+0	test-auc:1+0
# [12]	train-auc:1+0	test-auc:1+0
# [13]	train-auc:1+0	test-auc:1+0
# [14]	train-auc:1+0	test-auc:1+0
# [15]	train-auc:1+0	test-auc:1+0
# [16]	train-auc:1+0	test-auc:1+0
# [17]	train-auc:1+0	test-auc:1+0
# [18]	train-auc:1+0	test-auc:1+0
# [19]	train-auc:1+0	test-auc:1+0
# [20]	train-auc:1+0	test-auc:1+0
# [21]	train-auc:1+0	test-auc:1+0
# [22]	train-auc:1+0	test-auc:1+0
# [23]	train-auc:1+0	test-auc:1+0
# [24]	train-auc:1+0	test-auc:1+0
# [25]	train-auc:1+0	test-auc:1+0
# [26]	train-auc:1+0	test-auc:1+0
# [27]	train-auc:1+0	test-auc:1+0
# [28]	train-auc:1+0	test-auc:1+0
# [29]	train-auc:1+0	test-auc:1+0
# [30]	train-auc:1+0	test-auc:1+0
# [31]	train-auc:1+0	test-auc:1+0
# [32]	train-auc:1+0	test-auc:1+0
# [33]	train-auc:1+0	test-auc:1+0
# [34]	train-auc:1+0	test-auc:1+0
# [35]	train-auc:1+0	test-auc:1+0
# [36]	train-auc:1+0	test-auc:1+0
# [37]	train-auc:1+0	test-auc:1+0
# [38]	train-auc:1+0	test-auc:1+0
# [39]	train-auc:1+0	test-auc:1+0
# [40]	train-auc:1+0	test-auc:1+0
# [41]	train-auc:1+0	test-auc:1+0
# [42]	train-auc:1+0	test-auc:1+0
# [43]	train-auc:1+0	test-auc:1+0
# [44]	train-auc:1+0	test-auc:1+0
# [45]	train-auc:1+0	test-auc:1+0
# [46]	train-auc:1+0	test-auc:1+0
# [47]	train-auc:1+0	test-auc:1+0
# [48]	train-auc:1+0	test-auc:1+0
# [49]	train-auc:1+0	test-auc:1+0
# [50]	train-auc:1+0	test-auc:1+0
# [51]	train-auc:1+0	test-auc:1+0
# [52]	train-auc:1+0	test-auc:1+0
# [53]	train-auc:1+0	test-auc:1+0
# [54]	train-auc:1+0	test-auc:1+0
# [55]	train-auc:1+0	test-auc:1+0
# [56]	train-auc:1+0	test-auc:1+0
# [57]	train-auc:1+0	test-auc:1+0
# [58]	train-auc:1+0	test-auc:1+0
# [59]	train-auc:1+0	test-auc:1+0
# [60]	train-auc:1+0	test-auc:1+0
# [61]	train-auc:1+0	test-auc:1+0
# [62]	train-auc:1+0	test-auc:1+0
# [63]	train-auc:1+0	test-auc:1+0
# [64]	train-auc:1+0	test-auc:1+0
# [65]	train-auc:1+0	test-auc:1+0
# [66]	train-auc:1+0	test-auc:1+0
# [67]	train-auc:1+0	test-auc:1+0
# [68]	train-auc:1+0	test-auc:1+0
# [69]	train-auc:1+0	test-auc:1+0
# [70]	train-auc:1+0	test-auc:1+0
# [71]	train-auc:1+0	test-auc:1+0
# [72]	train-auc:1+0	test-auc:1+0
# [73]	train-auc:1+0	test-auc:1+0
# [74]	train-auc:1+0	test-auc:1+0
# [75]	train-auc:1+0	test-auc:1+0
# [76]	train-auc:1+0	test-auc:1+0
# [77]	train-auc:1+0	test-auc:1+0
# [78]	train-auc:1+0	test-auc:1+0
# [79]	train-auc:1+0	test-auc:1+0
# [80]	train-auc:1+0	test-auc:1+0
# [81]	train-auc:1+0	test-auc:1+0
# [82]	train-auc:1+0	test-auc:1+0
# [83]	train-auc:1+0	test-auc:1+0
# [84]	train-auc:1+0	test-auc:1+0
# [85]	train-auc:1+0	test-auc:1+0
# [86]	train-auc:1+0	test-auc:1+0
# [87]	train-auc:1+0	test-auc:1+0
# [88]	train-auc:1+0	test-auc:1+0
# [89]	train-auc:1+0	test-auc:1+0
# [90]	train-auc:1+0	test-auc:1+0
# [91]	train-auc:1+0	test-auc:1+0
# [92]	train-auc:1+0	test-auc:1+0
# [93]	train-auc:1+0	test-auc:1+0
# [94]	train-auc:1+0	test-auc:1+0
# [95]	train-auc:1+0	test-auc:1+0
# [96]	train-auc:1+0	test-auc:1+0
# [97]	train-auc:1+0	test-auc:1+0
# [98]	train-auc:1+0	test-auc:1+0
# [99]	train-auc:1+0	test-auc:1+0
